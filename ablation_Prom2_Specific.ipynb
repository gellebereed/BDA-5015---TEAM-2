# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Load the data
superstore_data = pd.read_csv('Superstore_RAW.csv', encoding='latin1')

# Clean the dataset
# 1. Standardize column names
superstore_data.columns = superstore_data.columns.str.strip().str.lower().str.replace(' ', '_')

# 2. Drop rows with missing 'region' or 'profit'
superstore_data = superstore_data.dropna(subset=['region', 'profit'])

# 3. Ensure 'profit' is numeric
superstore_data['profit'] = pd.to_numeric(superstore_data['profit'], errors='coerce')
superstore_data = superstore_data.dropna(subset=['profit'])

# Analyze total profit by region
profit_by_region = superstore_data.groupby('region')['profit'].sum().sort_values(ascending=False)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
profit_by_region.plot(kind='bar')
plt.title('Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')

# Set up the file path to save the plot
desktop = Path.home() / "Desktop"
save_path = desktop / "RAWP2V2"
save_path.mkdir(parents=True, exist_ok=True)

# Save the plot as a PNG file
save_file_path = save_path / "Trial1.png"
plt.tight_layout()  # Adjust layout to prevent overlap
plt.savefig(save_file_path)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Load the data
superstore_data = pd.read_csv('Superstore_RAW.csv', encoding='latin1')

# Clean the dataset
# Drop rows with missing 'profit' or 'region'
cleaned_data = superstore_data.dropna(subset=['profit', 'region'])

# Standardize column names (optional but good practice)
cleaned_data.columns = cleaned_data.columns.str.strip().str.lower().str.replace(' ', '_')

# Group by region and calculate total profit
profit_by_region = cleaned_data.groupby('region')['profit'].sum().sort_values(ascending=False)

# Set up the file path to save the plot
desktop = Path.home() / "Desktop"
save_path = desktop / "RAWP2V2"
save_path.mkdir(parents=True, exist_ok=True)
save_file_path = save_path / "Trial2.png"

# Create bar chart
plt.figure(figsize=(8, 6))
profit_by_region.plot(kind='bar')
plt.title('Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.xticks(rotation=45)
plt.tight_layout()  # Adjust layout to prevent overlap

# Save the plot
plt.savefig(save_file_path)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# 1. Veriyi yükle
superstore_data = pd.read_csv('Superstore_RAW.csv', encoding='latin1')

# 2. Kolon isimlerini temizle
superstore_data.columns = superstore_data.columns.str.strip().str.lower().str.replace(' ', '_')

# 3. Gerekli sütunlarda eksik değerleri temizle
superstore_cleaned = superstore_data.dropna(subset=['region', 'profit'])

# 4. Bölgelere göre toplam kârı hesapla
profit_by_region = superstore_cleaned.groupby('region')['profit'].sum().sort_values(ascending=False)

# 5. Grafik oluştur
plt.figure(figsize=(10, 6))
profit_by_region.plot(kind='bar')
plt.title('Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# 6. Grafik kaydedilecek yolu oluştur
desktop = Path.home() / "Desktop"
save_path = desktop / "RAWP2V2"
save_path.mkdir(parents=True, exist_ok=True)
save_file_path = save_path / "Trial3.png"

# 7. Grafiği kaydet
plt.savefig(save_file_path)

# 8. Grafiği göster
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Veriyi yükle
superstore_data = pd.read_csv('Superstore_RAW.csv', encoding='latin1')

# Sütun isimlerini temizle (küçük harf, boşluk yerine alt çizgi)
superstore_data.columns = superstore_data.columns.str.strip().str.lower().str.replace(" ", "_")

# 'sales' sütununu sayısala çevir
superstore_data['sales'] = pd.to_numeric(superstore_data['sales'], errors='coerce')

# Eksik 'profit' veya 'region' verilerini çıkar
cleaned_data = superstore_data.dropna(subset=['profit', 'region'])

# Bölgelere göre toplam kârı hesapla
profit_by_region = cleaned_data.groupby('region')['profit'].sum().sort_values(ascending=False)

# Grafik çizimi
plt.figure(figsize=(10, 6))
profit_by_region.plot(kind='bar')
plt.title('Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Masaüstüne kaydetme yolu
desktop = Path.home() / "Desktop"
save_path = desktop / "RAWP2V2"
save_path.mkdir(parents=True, exist_ok=True)
save_file_path = save_path / "Trial4.png"

# Grafiği kaydet ve göster
plt.tight_layout()
plt.savefig(save_file_path)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Veriyi yükle
superstore_data = pd.read_csv('Superstore_RAW.csv', encoding='latin1')

# Sütun adlarını temizle
superstore_data.columns = superstore_data.columns.str.strip().str.lower().str.replace(' ', '_')

# Eksik değerleri temizle
cleaned_data = superstore_data.dropna(subset=['region', 'profit'])

# 'profit' sütununu sayısal formata çevir
cleaned_data['profit'] = pd.to_numeric(cleaned_data['profit'], errors='coerce')

# Bölgeye göre toplam karı hesapla
profit_by_region = cleaned_data.groupby('region')['profit'].sum().sort_values(ascending=False)

# Grafik oluştur
plt.figure(figsize=(10, 6))
profit_by_region.plot(kind='bar')
plt.title('Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Masaüstüne kaydetme yolu
desktop = Path.home() / "Desktop"
save_path = desktop / "RAWP2V2"
save_path.mkdir(parents=True, exist_ok=True)
save_file_path = save_path / "Trial5.png"

# Grafiği kaydet
plt.tight_layout()
plt.savefig(save_file_path)

# Grafiği göster
plt.show()
# Out:
# /var/folders/91/h47bbf6x0_g7tvv4d838tzzw0000gn/T/ipykernel_2240/1582024083.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['profit'] = pd.to_numeric(cleaned_data['profit'], errors='coerce')
